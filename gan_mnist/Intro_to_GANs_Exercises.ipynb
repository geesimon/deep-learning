# %% [markdown]
# # Generative Adversarial Network
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the MNIST dataset. From this, we'll be able to generate new handwritten digits!
#
# GANs were [first reported on](https://arxiv.org/abs/1406.2661) in 2014 from Ian Goodfellow and others in Yoshua Bengio's lab. Since then, GANs have exploded in popularity. Here are a few examples to check out:
#
# * [Pix2Pix](https://affinelayer.com/pixsrv/)
# * [CycleGAN](https://github.com/junyanz/CycleGAN)
# * [A whole list](https://github.com/wiseodd/generative-models)
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes fake data to pass to the discriminator. The discriminator also sees real data and predicts if the data it's received is real or fake. The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real data. And the discriminator is trained to figure out which data is real and which is fake. What ends up happening is that the generator learns to make data that is indistiguishable from real data to the discriminator.
#
# ![GAN diagram](assets/gan_diagram.png)
#
# The general structure of a GAN is shown in the diagram above, using MNIST images as data. The latent sample is a random vector the generator uses to contruct it's fake images. As the generator learns through training, it figures out how to map these random vectors to recognizable images that can fool the discriminator.
#
# The output of the discriminator is a sigmoid function, where 0 indicates a fake image and 1 indicates an real image. If you're interested only in generating new images, you can throw out the discriminator after training. Now, let's see how we build this thing in TensorFlow.

# %%
# %matplotlib inline

import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')
# Out:
# WARNING:tensorflow:From <ipython-input-2-3efd1c79f029>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\geesi\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\geesi\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\geesi\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\geesi\Anaconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ## Model Inputs
#
# First we need to create the inputs for our graph. We need two inputs, one for the discriminator and one for the generator. Here we'll call the discriminator input `inputs_real` and the generator input `inputs_z`. We'll assign them the appropriate sizes for each of the networks.
#
# >**Exercise:** Finish the `model_inputs` function below. Create the placeholders for `inputs_real` and `inputs_z` using the input sizes `real_dim` and `z_dim` respectively.

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, shape=[None, real_dim])
    inputs_z = tf.placeholder(tf.float32, shape=[None, z_dim])
    
    return inputs_real, inputs_z

# %% [markdown]
# ## Generator network
#
# ![GAN Network](assets/gan_network.png)
#
# Here we'll build the generator network. To make this network a universal function approximator, we'll need at least one hidden layer. We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# #### Variable Scope
# Here we need to use `tf.variable_scope` for two reasons. Firstly, we're going to make sure all the variable names start with `generator`. Similarly, we'll prepend `discriminator` to the discriminator variables. This will help out later when we're training the separate networks.
#
# We could just use `tf.name_scope` to set the names, but we also want to reuse these networks with different inputs. For the generator, we're going to train it, but also _sample from it_ as we're training and after training. The discriminator will need to share variables between the fake and real input images. So, we can use the `reuse` keyword for `tf.variable_scope` to tell TensorFlow to reuse the variables instead of creating new ones if we build the graph again.
#
# To use `tf.variable_scope`, you use a `with` statement:
# ```python
# with tf.variable_scope('scope_name', reuse=False):
#     # code here
# ```
#
# Here's more from [the TensorFlow documentation](https://www.tensorflow.org/programmers_guide/variable_scope#the_problem) to get another look at using `tf.variable_scope`.
#
# #### Leaky ReLU
# TensorFlow doesn't provide an operation for leaky ReLUs, so we'll need to make one . For this you can just take the outputs from a linear fully connected layer and pass them to `tf.maximum`. Typically, a parameter `alpha` sets the magnitude of the output for negative values. So, the output for negative input (`x`) values is `alpha*x`, and the output for positive `x` is `x`:
# $$
# f(x) = max(\alpha * x, x)
# $$
#
# #### Tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output. This means that we'll have to rescale the MNIST images to be between -1 and 1, instead of 0 and 1.
#
# >**Exercise:** Implement the generator network in the function below. You'll need to return the tanh output. Make sure to wrap your code in a variable scope, with 'generator' as the scope name, and pass the `reuse` keyword argument from the function to `tf.variable_scope`.

# %%
def generator(z, out_dim, n_units=128, reuse=False,  alpha=0.01):
    ''' Build the generator network.
    
        Arguments
        ---------
        z : Input tensor for the generator
        out_dim : Shape of the generator output
        n_units : Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out: 
    '''
    with tf.variable_scope('generator', reuse=reuse): # finish this
        # Hidden layer
        h1 = tf.layers.dense(z, n_units)
        # Leaky ReLU
        h1 = tf.maximum(h1 * alpha, h1)
        
        # Logits and tanh output
        logits = tf.layers.dense(h1, out_dim)
        out = tf.tanh(logits)
        
        return out

# %% [markdown]
# ## Discriminator
#
# The discriminator network is almost exactly the same as the generator network, except that we're using a sigmoid output layer.
#
# >**Exercise:** Implement the discriminator network in the function below. Same as above, you'll need to return both the logits and the sigmoid output. Make sure to wrap your code in a variable scope, with 'discriminator' as the scope name, and pass the `reuse` keyword argument from the function arguments to `tf.variable_scope`.

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    ''' Build the discriminator network.
    
        Arguments
        ---------
        x : Input tensor for the discriminator
        n_units: Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out, logits: 
    '''
    with tf.variable_scope('discriminator', reuse = reuse): # finish this
        # Hidden layer
        h1 = tf.layers.dense(x, n_units)
        # Leaky ReLU
        h1 = tf.maximum(h1 * alpha, h1)
        
        logits = tf.layers.dense(h1, 1)
        out = tf.sigmoid(logits)
        
        return out, logits

# %% [markdown]
# ## Hyperparameters

# %%
# Size of input image to discriminator
input_size = 784 # 28x28 MNIST images flattened
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 128
d_hidden_size = 128
# Leak factor for leaky ReLU
alpha = 0.01
# Label smoothing 
smooth = 0.1

# %% [markdown]
# ## Build network
#
# Now we're building the network from the functions defined above.
#
# First is to get our inputs, `input_real, input_z` from `model_inputs` using the sizes of the input and z.
#
# Then, we'll create the generator, `generator(input_z, input_size)`. This builds the generator with the appropriate input and output sizes.
#
# Then the discriminators. We'll build two of them, one for real data and one for fake data. Since we want the weights to be the same for both real and fake data, we need to reuse the variables. For the fake data, we're getting it from the generator as `g_model`. So the real data discriminator is `discriminator(input_real)` while the fake discriminator is `discriminator(g_model, reuse=True)`.
#
# >**Exercise:** Build the network from the functions you defined earlier.

# %%
tf.reset_default_graph()
# Create our input placeholders
input_real, input_z = model_inputs(input_size, z_size)

# Generator network here
g_model = generator(input_z, input_size, n_units=g_hidden_size, reuse=False,  alpha=alpha)
# g_model is the generator output

# Disriminator network here
d_model_real, d_logits_real = discriminator(input_real, n_units=d_hidden_size, alpha=alpha)
d_model_fake, d_logits_fake = discriminator(g_model, n_units=d_hidden_size, reuse=True, alpha=alpha)

# %% [markdown]
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses, which is a little tricky. For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_loss_real + d_loss_fake`. The losses will by sigmoid cross-entropies, which we can get with `tf.nn.sigmoid_cross_entropy_with_logits`. We'll also wrap that in `tf.reduce_mean` to get the mean for all the images in the batch. So the losses will look something like
#
# ```python
# tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=labels))
# ```
#
# For the real image logits, we'll use `d_logits_real` which we got from the discriminator in the cell above. For the labels, we want them to be all ones, since these are all real images. To help the discriminator generalize better, the labels are reduced a bit from 1.0 to 0.9, for example,  using the parameter `smooth`. This is known as label smoothing, typically used with classifiers to improve performance. In TensorFlow, it looks something like `labels = tf.ones_like(tensor) * (1 - smooth)`
#
# The discriminator loss for the fake data is similar. The logits are `d_logits_fake`, which we got from passing the generator output to the discriminator. These fake logits are used with labels of all zeros. Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# Finally, the generator losses are using `d_logits_fake`, the fake image logits. But, now the labels are all ones. The generator is trying to fool the discriminator, so it wants to discriminator to output ones for fake images.
#
# >**Exercise:** Calculate the losses for the discriminator and the generator. There are two discriminator losses, one for real images and one for fake images. For the real image loss, use the real logits and (smoothed) labels of ones. For the fake image loss, use the fake logits with labels of all zeros. The total discriminator loss is the sum of those two losses. Finally, the generator loss again uses the fake logits from the discriminator, but this time the labels are all ones because the generator wants to fool the discriminator.

# %%
# Calculate losses
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                     labels=tf.ones_like(d_model_real) * (1 - smooth)))

d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.zeros_like(d_model_fake)))

d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.ones_like(d_model_fake)))

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So we need to get the variables for each part and build optimizers for the two parts. To get all the trainable variables, we use `tf.trainable_variables()`. This creates a list of all the variables we've defined in our graph.
#
# For the generator optimizer, we only want to generator variables. Our past selves were nice and used a variable scope to start all of our generator variable names with `generator`. So, we just need to iterate through the list from `tf.trainable_variables()` and keep variables that start with `generator`. Each variable object has an attribute `name` which holds the name of the variable as a string (`var.name == 'weights_0'` for instance).
#
# We can do something similar with the discriminator. All the variables in the discriminator start with `discriminator`.
#
# Then, in the optimizer we pass the variable lists to the `var_list` keyword argument of the `minimize` method. This tells the optimizer to only update the listed variables. Something like `tf.train.AdamOptimizer().minimize(loss, var_list=var_list)` will only train the variables in `var_list`.
#
# >**Exercise: ** Below, implement the optimizers for the generator and discriminator. First you'll need to get a list of trainable variables, then split that list into two lists, one for the generator variables and another for the discriminator variables. Finally, using `AdamOptimizer`, create an optimizer for each network that update the network variables separately.

# %%
# Optimizers
learning_rate = 0.002

# Get the trainable_variables, split into G and D parts
t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator') ]
d_vars = [var for var in t_vars if var.name.startswith('discriminator') ]

d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars) 
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %% [markdown]
# ## Training

# %%
batch_size = 100
epochs = 1000
samples = []
losses = []
saver = tf.train.Saver(var_list = g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            # Get images, reshape and rescale to pass to D
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
        losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/1000... Discriminator Loss: 0.3576... Generator Loss: 3.9291
# Epoch 2/1000... Discriminator Loss: 0.3532... Generator Loss: 4.4814
# Epoch 3/1000... Discriminator Loss: 0.3693... Generator Loss: 3.7073
# Epoch 4/1000... Discriminator Loss: 0.8657... Generator Loss: 2.0962
# Epoch 5/1000... Discriminator Loss: 0.5257... Generator Loss: 4.2193
# Epoch 6/1000... Discriminator Loss: 1.1883... Generator Loss: 3.9489
# Epoch 7/1000... Discriminator Loss: 1.0649... Generator Loss: 2.1092
# Epoch 8/1000... Discriminator Loss: 0.7752... Generator Loss: 3.0805
# Epoch 9/1000... Discriminator Loss: 0.7758... Generator Loss: 3.7732
# Epoch 10/1000... Discriminator Loss: 1.1883... Generator Loss: 1.8807
# Epoch 11/1000... Discriminator Loss: 0.8658... Generator Loss: 2.3398
# Epoch 12/1000... Discriminator Loss: 0.6525... Generator Loss: 3.5344
# Epoch 13/1000... Discriminator Loss: 0.9024... Generator Loss: 2.5373
# Epoch 14/1000... Discriminator Loss: 0.5927... Generator Loss: 3.3875
# Epoch 15/1000... Discriminator Loss: 0.7916... Generator Loss: 2.9750
# Epoch 16/1000... Discriminator Loss: 1.0518... Generator Loss: 1.7751
# Epoch 17/1000... Discriminator Loss: 0.7814... Generator Loss: 2.4490
# Epoch 18/1000... Discriminator Loss: 1.2705... Generator Loss: 3.0523
# Epoch 19/1000... Discriminator Loss: 1.0432... Generator Loss: 1.9732
# Epoch 20/1000... Discriminator Loss: 1.0069... Generator Loss: 2.0658
# Epoch 21/1000... Discriminator Loss: 0.9338... Generator Loss: 2.3123
# Epoch 22/1000... Discriminator Loss: 0.9463... Generator Loss: 2.0355
# Epoch 23/1000... Discriminator Loss: 0.8772... Generator Loss: 2.2875
# Epoch 24/1000... Discriminator Loss: 0.7445... Generator Loss: 2.2210
# Epoch 25/1000... Discriminator Loss: 0.7257... Generator Loss: 2.3797
# Epoch 26/1000... Discriminator Loss: 0.7274... Generator Loss: 1.9400
# Epoch 27/1000... Discriminator Loss: 0.9056... Generator Loss: 2.1949
# Epoch 28/1000... Discriminator Loss: 0.7705... Generator Loss: 2.2439
# Epoch 29/1000... Discriminator Loss: 0.8632... Generator Loss: 2.6601
# Epoch 30/1000... Discriminator Loss: 0.7570... Generator Loss: 2.0393
# Epoch 31/1000... Discriminator Loss: 0.7859... Generator Loss: 2.1892
# Epoch 32/1000... Discriminator Loss: 1.0338... Generator Loss: 2.2533
# Epoch 33/1000... Discriminator Loss: 0.8850... Generator Loss: 2.3507
# Epoch 34/1000... Discriminator Loss: 0.7669... Generator Loss: 2.7266
# Epoch 35/1000... Discriminator Loss: 1.0354... Generator Loss: 1.8543
# Epoch 36/1000... Discriminator Loss: 0.7160... Generator Loss: 2.3680
# Epoch 37/1000... Discriminator Loss: 0.8835... Generator Loss: 1.9516
# Epoch 38/1000... Discriminator Loss: 0.8720... Generator Loss: 2.1540
# Epoch 39/1000... Discriminator Loss: 0.8925... Generator Loss: 2.6269
# Epoch 40/1000... Discriminator Loss: 0.7849... Generator Loss: 2.1692
# Epoch 41/1000... Discriminator Loss: 0.8523... Generator Loss: 2.4340
# Epoch 42/1000... Discriminator Loss: 0.9557... Generator Loss: 2.8190
# Epoch 43/1000... Discriminator Loss: 1.1701... Generator Loss: 1.8121
# Epoch 44/1000... Discriminator Loss: 1.0287... Generator Loss: 2.0279
# Epoch 45/1000... Discriminator Loss: 0.8341... Generator Loss: 2.0740
# Epoch 46/1000... Discriminator Loss: 1.0206... Generator Loss: 2.1617
# Epoch 47/1000... Discriminator Loss: 0.9599... Generator Loss: 2.6273
# Epoch 48/1000... Discriminator Loss: 0.9969... Generator Loss: 1.9588
# Epoch 49/1000... Discriminator Loss: 0.8650... Generator Loss: 2.0789
# Epoch 50/1000... Discriminator Loss: 1.0470... Generator Loss: 2.4516
# Epoch 51/1000... Discriminator Loss: 0.9373... Generator Loss: 1.7092
# Epoch 52/1000... Discriminator Loss: 0.9240... Generator Loss: 1.9161
# Epoch 53/1000... Discriminator Loss: 1.0135... Generator Loss: 1.9719
# Epoch 54/1000... Discriminator Loss: 1.1597... Generator Loss: 1.6020
# Epoch 55/1000... Discriminator Loss: 1.0151... Generator Loss: 1.9105
# Epoch 56/1000... Discriminator Loss: 0.9326... Generator Loss: 2.1386
# Epoch 57/1000... Discriminator Loss: 0.9642... Generator Loss: 1.5501
# Epoch 58/1000... Discriminator Loss: 0.9358... Generator Loss: 2.0137
# Epoch 59/1000... Discriminator Loss: 1.0746... Generator Loss: 1.6300
# Epoch 60/1000... Discriminator Loss: 1.0115... Generator Loss: 1.7711
# Epoch 61/1000... Discriminator Loss: 1.1109... Generator Loss: 1.7657
# Epoch 62/1000... Discriminator Loss: 0.9436... Generator Loss: 2.0488
# Epoch 63/1000... Discriminator Loss: 0.9778... Generator Loss: 2.1619
# Epoch 64/1000... Discriminator Loss: 0.9793... Generator Loss: 1.8202
# Epoch 65/1000... Discriminator Loss: 0.9771... Generator Loss: 1.5575
# Epoch 66/1000... Discriminator Loss: 0.9952... Generator Loss: 1.9338
# Epoch 67/1000... Discriminator Loss: 0.8581... Generator Loss: 2.0164
# Epoch 68/1000... Discriminator Loss: 0.9791... Generator Loss: 1.8589
# Epoch 69/1000... Discriminator Loss: 0.8400... Generator Loss: 2.0234
# Epoch 70/1000... Discriminator Loss: 0.9394... Generator Loss: 1.9839
# Epoch 71/1000... Discriminator Loss: 0.9885... Generator Loss: 1.7935
# Epoch 72/1000... Discriminator Loss: 1.0160... Generator Loss: 1.7510
# Epoch 73/1000... Discriminator Loss: 1.0435... Generator Loss: 1.5745
# Epoch 74/1000... Discriminator Loss: 1.0672... Generator Loss: 1.7768
# Epoch 75/1000... Discriminator Loss: 1.0913... Generator Loss: 2.2767
# Epoch 76/1000... Discriminator Loss: 0.9012... Generator Loss: 1.9878
# Epoch 77/1000... Discriminator Loss: 1.0217... Generator Loss: 2.0112
# Epoch 78/1000... Discriminator Loss: 0.9469... Generator Loss: 2.0534
# Epoch 79/1000... Discriminator Loss: 1.0879... Generator Loss: 1.7328
# Epoch 80/1000... Discriminator Loss: 1.0066... Generator Loss: 1.7983
# Epoch 81/1000... Discriminator Loss: 0.7576... Generator Loss: 2.3673
# Epoch 82/1000... Discriminator Loss: 0.8599... Generator Loss: 2.2766
# Epoch 83/1000... Discriminator Loss: 0.9524... Generator Loss: 1.4668
# Epoch 84/1000... Discriminator Loss: 1.0104... Generator Loss: 1.8992
# Epoch 85/1000... Discriminator Loss: 0.9225... Generator Loss: 1.9973
# Epoch 86/1000... Discriminator Loss: 0.9326... Generator Loss: 2.2502
# Epoch 87/1000... Discriminator Loss: 0.7786... Generator Loss: 2.1971
# Epoch 88/1000... Discriminator Loss: 0.9658... Generator Loss: 2.2822
# Epoch 89/1000... Discriminator Loss: 1.0583... Generator Loss: 1.6024
# Epoch 90/1000... Discriminator Loss: 0.7930... Generator Loss: 2.5502
# Epoch 91/1000... Discriminator Loss: 0.9779... Generator Loss: 2.4383
# Epoch 92/1000... Discriminator Loss: 0.8145... Generator Loss: 1.8495
# Epoch 93/1000... Discriminator Loss: 0.8359... Generator Loss: 2.4469
# Epoch 94/1000... Discriminator Loss: 1.0512... Generator Loss: 2.0193
# Epoch 95/1000... Discriminator Loss: 0.8844... Generator Loss: 2.1164
# Epoch 96/1000... Discriminator Loss: 0.9482... Generator Loss: 1.6165
# Epoch 97/1000... Discriminator Loss: 0.9878... Generator Loss: 1.8208
# Epoch 98/1000... Discriminator Loss: 0.9894... Generator Loss: 2.0504
# Epoch 99/1000... Discriminator Loss: 0.9260... Generator Loss: 1.8467
# Epoch 100/1000... Discriminator Loss: 0.8852... Generator Loss: 1.8079
# Epoch 101/1000... Discriminator Loss: 0.9338... Generator Loss: 2.2421
# Epoch 102/1000... Discriminator Loss: 1.0605... Generator Loss: 1.6266
# Epoch 103/1000... Discriminator Loss: 1.0026... Generator Loss: 1.3993
# Epoch 104/1000... Discriminator Loss: 0.9836... Generator Loss: 1.9932
# Epoch 105/1000... Discriminator Loss: 1.1151... Generator Loss: 1.2290
# Epoch 106/1000... Discriminator Loss: 0.9762... Generator Loss: 2.0375
# Epoch 107/1000... Discriminator Loss: 1.0733... Generator Loss: 1.7166
# Epoch 108/1000... Discriminator Loss: 0.9413... Generator Loss: 1.8858
# Epoch 109/1000... Discriminator Loss: 0.9735... Generator Loss: 2.1143
# Epoch 110/1000... Discriminator Loss: 0.8637... Generator Loss: 2.2377
# Epoch 111/1000... Discriminator Loss: 0.9124... Generator Loss: 1.7615
# Epoch 112/1000... Discriminator Loss: 1.0190... Generator Loss: 1.9351
# Epoch 113/1000... Discriminator Loss: 1.1575... Generator Loss: 1.7826
# Epoch 114/1000... Discriminator Loss: 0.8312... Generator Loss: 2.1655
# Epoch 115/1000... Discriminator Loss: 1.0703... Generator Loss: 1.7678
# Epoch 116/1000... Discriminator Loss: 1.0037... Generator Loss: 1.8466
# Epoch 117/1000... Discriminator Loss: 1.1154... Generator Loss: 2.0327
# Epoch 118/1000... Discriminator Loss: 0.8642... Generator Loss: 2.4197
# Epoch 119/1000... Discriminator Loss: 0.8938... Generator Loss: 2.0394
# Epoch 120/1000... Discriminator Loss: 0.9202... Generator Loss: 1.9527
# Epoch 121/1000... Discriminator Loss: 0.9588... Generator Loss: 2.0230
# Epoch 122/1000... Discriminator Loss: 1.0919... Generator Loss: 1.7459
# Epoch 123/1000... Discriminator Loss: 0.9289... Generator Loss: 1.9383
# Epoch 124/1000... Discriminator Loss: 1.0473... Generator Loss: 1.9842
# Epoch 125/1000... Discriminator Loss: 0.9609... Generator Loss: 1.6860
# Epoch 126/1000... Discriminator Loss: 0.8131... Generator Loss: 2.2796
# Epoch 127/1000... Discriminator Loss: 0.9062... Generator Loss: 1.9576
# Epoch 128/1000... Discriminator Loss: 0.9659... Generator Loss: 1.3956
# Epoch 129/1000... Discriminator Loss: 0.9146... Generator Loss: 1.8163
# Epoch 130/1000... Discriminator Loss: 0.9074... Generator Loss: 1.8427
# Epoch 131/1000... Discriminator Loss: 1.0665... Generator Loss: 1.7152
# Epoch 132/1000... Discriminator Loss: 1.0503... Generator Loss: 1.6017
# Epoch 133/1000... Discriminator Loss: 0.9288... Generator Loss: 1.8279
# Epoch 134/1000... Discriminator Loss: 0.9800... Generator Loss: 1.6475
# Epoch 135/1000... Discriminator Loss: 0.9856... Generator Loss: 1.5947
# Epoch 136/1000... Discriminator Loss: 1.1387... Generator Loss: 1.6218
# Epoch 137/1000... Discriminator Loss: 0.9830... Generator Loss: 1.9605
# Epoch 138/1000... Discriminator Loss: 0.8479... Generator Loss: 1.7405
# Epoch 139/1000... Discriminator Loss: 1.1137... Generator Loss: 2.2626
# Epoch 140/1000... Discriminator Loss: 0.8832... Generator Loss: 2.2938
# Epoch 141/1000... Discriminator Loss: 1.0631... Generator Loss: 1.6026
# Epoch 142/1000... Discriminator Loss: 0.9738... Generator Loss: 2.1055
# Epoch 143/1000... Discriminator Loss: 1.0619... Generator Loss: 1.7592
# Epoch 144/1000... Discriminator Loss: 0.9220... Generator Loss: 1.7835
# Epoch 145/1000... Discriminator Loss: 0.9383... Generator Loss: 1.9712
# Epoch 146/1000... Discriminator Loss: 1.2875... Generator Loss: 1.7042
# Epoch 147/1000... Discriminator Loss: 1.0967... Generator Loss: 1.5528
# Epoch 148/1000... Discriminator Loss: 1.1277... Generator Loss: 1.5864
# Epoch 149/1000... Discriminator Loss: 1.0002... Generator Loss: 1.7412
# Epoch 150/1000... Discriminator Loss: 0.9249... Generator Loss: 2.2708
# Epoch 151/1000... Discriminator Loss: 0.8493... Generator Loss: 2.1200
# Epoch 152/1000... Discriminator Loss: 1.1753... Generator Loss: 1.5506
# Epoch 153/1000... Discriminator Loss: 0.8707... Generator Loss: 2.1092
# Epoch 154/1000... Discriminator Loss: 0.8354... Generator Loss: 2.6017
# Epoch 155/1000... Discriminator Loss: 0.9087... Generator Loss: 1.8770
# Epoch 156/1000... Discriminator Loss: 1.0427... Generator Loss: 1.8161
# Epoch 157/1000... Discriminator Loss: 0.8560... Generator Loss: 2.2221
# Epoch 158/1000... Discriminator Loss: 1.0867... Generator Loss: 1.6028
# Epoch 159/1000... Discriminator Loss: 0.9554... Generator Loss: 1.8942
# Epoch 160/1000... Discriminator Loss: 0.9812... Generator Loss: 1.8862
# Epoch 161/1000... Discriminator Loss: 1.0378... Generator Loss: 1.5877
# Epoch 162/1000... Discriminator Loss: 1.0563... Generator Loss: 1.4618
# Epoch 163/1000... Discriminator Loss: 1.1383... Generator Loss: 1.4836
# Epoch 164/1000... Discriminator Loss: 0.7758... Generator Loss: 2.1902
# Epoch 165/1000... Discriminator Loss: 1.1253... Generator Loss: 1.6433
# Epoch 166/1000... Discriminator Loss: 0.9946... Generator Loss: 2.2740
# Epoch 167/1000... Discriminator Loss: 0.9163... Generator Loss: 1.9129
# Epoch 168/1000... Discriminator Loss: 0.9586... Generator Loss: 2.2123
# Epoch 169/1000... Discriminator Loss: 0.8624... Generator Loss: 1.9467
# Epoch 170/1000... Discriminator Loss: 0.9459... Generator Loss: 1.7054
# Epoch 171/1000... Discriminator Loss: 0.9115... Generator Loss: 1.9121
# Epoch 172/1000... Discriminator Loss: 0.9442... Generator Loss: 1.7862
# Epoch 173/1000... Discriminator Loss: 1.1225... Generator Loss: 1.6982
# Epoch 174/1000... Discriminator Loss: 1.3295... Generator Loss: 1.6651
# Epoch 175/1000... Discriminator Loss: 0.9654... Generator Loss: 1.8228
# Epoch 176/1000... Discriminator Loss: 1.1035... Generator Loss: 1.5382
# Epoch 177/1000... Discriminator Loss: 0.9934... Generator Loss: 1.7746
# Epoch 178/1000... Discriminator Loss: 1.1834... Generator Loss: 1.8924
# Epoch 179/1000... Discriminator Loss: 0.9185... Generator Loss: 1.8823
# Epoch 180/1000... Discriminator Loss: 1.1224... Generator Loss: 2.2429
# Epoch 181/1000... Discriminator Loss: 0.9873... Generator Loss: 2.0714
# Epoch 182/1000... Discriminator Loss: 0.9738... Generator Loss: 2.0574
# Epoch 183/1000... Discriminator Loss: 0.9210... Generator Loss: 2.4606
# Epoch 184/1000... Discriminator Loss: 1.1331... Generator Loss: 1.5485
# Epoch 185/1000... Discriminator Loss: 0.9026... Generator Loss: 2.0565
# Epoch 186/1000... Discriminator Loss: 1.0039... Generator Loss: 1.9934
# Epoch 187/1000... Discriminator Loss: 0.9125... Generator Loss: 2.4406
# Epoch 188/1000... Discriminator Loss: 0.9932... Generator Loss: 1.8363
# Epoch 189/1000... Discriminator Loss: 0.9990... Generator Loss: 1.6667
# Epoch 190/1000... Discriminator Loss: 1.0611... Generator Loss: 1.8716
# Epoch 191/1000... Discriminator Loss: 0.8974... Generator Loss: 2.2225
# Epoch 192/1000... Discriminator Loss: 0.9998... Generator Loss: 1.6171
# Epoch 193/1000... Discriminator Loss: 1.0011... Generator Loss: 1.8923
# Epoch 194/1000... Discriminator Loss: 1.0103... Generator Loss: 1.9885
# Epoch 195/1000... Discriminator Loss: 0.9340... Generator Loss: 2.2892
# Epoch 196/1000... Discriminator Loss: 1.1179... Generator Loss: 1.7584
# Epoch 197/1000... Discriminator Loss: 1.0311... Generator Loss: 1.9159
# Epoch 198/1000... Discriminator Loss: 0.8097... Generator Loss: 2.0091
# Epoch 199/1000... Discriminator Loss: 0.8104... Generator Loss: 2.2483
# Epoch 200/1000... Discriminator Loss: 1.0335... Generator Loss: 1.8032
# Epoch 201/1000... Discriminator Loss: 1.0271... Generator Loss: 2.2395
# Epoch 202/1000... Discriminator Loss: 1.0235... Generator Loss: 1.9607
# Epoch 203/1000... Discriminator Loss: 0.8616... Generator Loss: 1.8872
# Epoch 204/1000... Discriminator Loss: 1.0021... Generator Loss: 2.1464
# Epoch 205/1000... Discriminator Loss: 1.0200... Generator Loss: 1.8810
# Epoch 206/1000... Discriminator Loss: 1.1677... Generator Loss: 1.4877
# Epoch 207/1000... Discriminator Loss: 0.9393... Generator Loss: 1.9475
# Epoch 208/1000... Discriminator Loss: 1.1556... Generator Loss: 2.1733
# Epoch 209/1000... Discriminator Loss: 1.0730... Generator Loss: 1.8691
# Epoch 210/1000... Discriminator Loss: 0.9720... Generator Loss: 1.9685
# Epoch 211/1000... Discriminator Loss: 0.9200... Generator Loss: 2.0252
# Epoch 212/1000... Discriminator Loss: 1.0303... Generator Loss: 2.1132
# Epoch 213/1000... Discriminator Loss: 1.0398... Generator Loss: 2.1812
# Epoch 214/1000... Discriminator Loss: 0.9058... Generator Loss: 1.9080
# Epoch 215/1000... Discriminator Loss: 0.9749... Generator Loss: 2.0049
# Epoch 216/1000... Discriminator Loss: 0.9793... Generator Loss: 1.8832
# Epoch 217/1000... Discriminator Loss: 1.0849... Generator Loss: 1.5537
# Epoch 218/1000... Discriminator Loss: 1.0485... Generator Loss: 1.5339
# Epoch 219/1000... Discriminator Loss: 1.0312... Generator Loss: 2.0217
# Epoch 220/1000... Discriminator Loss: 0.8414... Generator Loss: 2.2337
# Epoch 221/1000... Discriminator Loss: 1.2377... Generator Loss: 1.6081
# Epoch 222/1000... Discriminator Loss: 1.1361... Generator Loss: 2.0883
# Epoch 223/1000... Discriminator Loss: 0.9789... Generator Loss: 2.0428
# Epoch 224/1000... Discriminator Loss: 0.9709... Generator Loss: 1.6992
# Epoch 225/1000... Discriminator Loss: 0.9769... Generator Loss: 2.1901
# Epoch 226/1000... Discriminator Loss: 1.1755... Generator Loss: 1.6442
# Epoch 227/1000... Discriminator Loss: 0.9936... Generator Loss: 1.5311
# Epoch 228/1000... Discriminator Loss: 1.0266... Generator Loss: 1.9263
# Epoch 229/1000... Discriminator Loss: 0.9168... Generator Loss: 1.8996
# Epoch 230/1000... Discriminator Loss: 0.9557... Generator Loss: 2.2769
# Epoch 231/1000... Discriminator Loss: 1.0605... Generator Loss: 1.6783
# Epoch 232/1000... Discriminator Loss: 1.1164... Generator Loss: 1.7937
# Epoch 233/1000... Discriminator Loss: 1.1046... Generator Loss: 1.7502
# Epoch 234/1000... Discriminator Loss: 0.9866... Generator Loss: 1.9373
# Epoch 235/1000... Discriminator Loss: 1.1034... Generator Loss: 2.0483
# Epoch 236/1000... Discriminator Loss: 1.0877... Generator Loss: 1.6011
# Epoch 237/1000... Discriminator Loss: 1.0829... Generator Loss: 1.6273
# Epoch 238/1000... Discriminator Loss: 0.9806... Generator Loss: 1.5279
# Epoch 239/1000... Discriminator Loss: 1.0396... Generator Loss: 1.7094
# Epoch 240/1000... Discriminator Loss: 0.9661... Generator Loss: 1.7689
# Epoch 241/1000... Discriminator Loss: 0.9539... Generator Loss: 2.3558
# Epoch 242/1000... Discriminator Loss: 1.0159... Generator Loss: 2.0693
# Epoch 243/1000... Discriminator Loss: 0.9769... Generator Loss: 1.7752
# Epoch 244/1000... Discriminator Loss: 0.9891... Generator Loss: 1.8823
# Epoch 245/1000... Discriminator Loss: 1.1010... Generator Loss: 2.0345
# Epoch 246/1000... Discriminator Loss: 1.0051... Generator Loss: 2.0133
# Epoch 247/1000... Discriminator Loss: 1.0931... Generator Loss: 2.0779
# Epoch 248/1000... Discriminator Loss: 0.8043... Generator Loss: 2.1710
# Epoch 249/1000... Discriminator Loss: 1.3870... Generator Loss: 2.1989
# Epoch 250/1000... Discriminator Loss: 1.1510... Generator Loss: 2.1552
# Epoch 251/1000... Discriminator Loss: 0.8278... Generator Loss: 2.0537
# Epoch 252/1000... Discriminator Loss: 1.0157... Generator Loss: 1.9112
# Epoch 253/1000... Discriminator Loss: 0.8838... Generator Loss: 2.3160
# Epoch 254/1000... Discriminator Loss: 1.0826... Generator Loss: 1.9356
# Epoch 255/1000... Discriminator Loss: 1.0498... Generator Loss: 1.8504
# Epoch 256/1000... Discriminator Loss: 1.1322... Generator Loss: 2.0223
# Epoch 257/1000... Discriminator Loss: 0.9785... Generator Loss: 1.8698
# Epoch 258/1000... Discriminator Loss: 0.9307... Generator Loss: 2.1623
# Epoch 259/1000... Discriminator Loss: 1.1683... Generator Loss: 1.3259
# Epoch 260/1000... Discriminator Loss: 0.8697... Generator Loss: 1.9478
# Epoch 261/1000... Discriminator Loss: 1.1445... Generator Loss: 1.5215
# Epoch 262/1000... Discriminator Loss: 0.7665... Generator Loss: 2.5964
# Epoch 263/1000... Discriminator Loss: 0.8865... Generator Loss: 1.9252
# Epoch 264/1000... Discriminator Loss: 1.0644... Generator Loss: 1.9010
# Epoch 265/1000... Discriminator Loss: 1.0701... Generator Loss: 1.4616
# Epoch 266/1000... Discriminator Loss: 0.9903... Generator Loss: 1.9105
# Epoch 267/1000... Discriminator Loss: 0.8217... Generator Loss: 2.2767
# Epoch 268/1000... Discriminator Loss: 0.8907... Generator Loss: 1.9924
# Epoch 269/1000... Discriminator Loss: 0.9513... Generator Loss: 1.7652
# Epoch 270/1000... Discriminator Loss: 0.9997... Generator Loss: 1.6526
# Epoch 271/1000... Discriminator Loss: 0.8514... Generator Loss: 1.8291
# Epoch 272/1000... Discriminator Loss: 1.0839... Generator Loss: 1.8142
# Epoch 273/1000... Discriminator Loss: 0.8377... Generator Loss: 2.2381
# Epoch 274/1000... Discriminator Loss: 0.9335... Generator Loss: 2.4304
# Epoch 275/1000... Discriminator Loss: 1.1289... Generator Loss: 1.4941
# Epoch 276/1000... Discriminator Loss: 1.0675... Generator Loss: 1.6122
# Epoch 277/1000... Discriminator Loss: 0.9485... Generator Loss: 2.0458
# Epoch 278/1000... Discriminator Loss: 1.0522... Generator Loss: 1.8625
# Epoch 279/1000... Discriminator Loss: 1.0583... Generator Loss: 1.4035
# Epoch 280/1000... Discriminator Loss: 1.0249... Generator Loss: 1.6266
# Epoch 281/1000... Discriminator Loss: 1.1776... Generator Loss: 1.6748
# Epoch 282/1000... Discriminator Loss: 0.8616... Generator Loss: 2.1377
# Epoch 283/1000... Discriminator Loss: 0.9739... Generator Loss: 2.0527
# Epoch 284/1000... Discriminator Loss: 1.0299... Generator Loss: 1.8296
# Epoch 285/1000... Discriminator Loss: 1.1560... Generator Loss: 1.4355
# Epoch 286/1000... Discriminator Loss: 0.9574... Generator Loss: 2.0343
# Epoch 287/1000... Discriminator Loss: 1.0981... Generator Loss: 1.5609
# Epoch 288/1000... Discriminator Loss: 0.9410... Generator Loss: 1.8598
# Epoch 289/1000... Discriminator Loss: 1.0072... Generator Loss: 2.1397
# Epoch 290/1000... Discriminator Loss: 1.0482... Generator Loss: 1.7906
# Epoch 291/1000... Discriminator Loss: 1.0346... Generator Loss: 1.5766
# Epoch 292/1000... Discriminator Loss: 0.9450... Generator Loss: 1.9736
# Epoch 293/1000... Discriminator Loss: 1.1335... Generator Loss: 1.7252
# Epoch 294/1000... Discriminator Loss: 0.9248... Generator Loss: 2.1182
# Epoch 295/1000... Discriminator Loss: 0.9041... Generator Loss: 1.7284
# Epoch 296/1000... Discriminator Loss: 0.9789... Generator Loss: 1.8688
# Epoch 297/1000... Discriminator Loss: 0.8487... Generator Loss: 2.5319
# Epoch 298/1000... Discriminator Loss: 0.9507... Generator Loss: 2.0033
# Epoch 299/1000... Discriminator Loss: 0.8767... Generator Loss: 2.1399
# Epoch 300/1000... Discriminator Loss: 0.9630... Generator Loss: 1.9185
# Epoch 301/1000... Discriminator Loss: 0.9133... Generator Loss: 2.4056
# Epoch 302/1000... Discriminator Loss: 0.9571... Generator Loss: 2.0309
# Epoch 303/1000... Discriminator Loss: 0.9704... Generator Loss: 1.9437
# Epoch 304/1000... Discriminator Loss: 0.8713... Generator Loss: 2.1616
# Epoch 305/1000... Discriminator Loss: 0.8999... Generator Loss: 1.9736
# Epoch 306/1000... Discriminator Loss: 1.0747... Generator Loss: 1.6226
# Epoch 307/1000... Discriminator Loss: 0.8959... Generator Loss: 2.1470
# Epoch 308/1000... Discriminator Loss: 1.0396... Generator Loss: 1.8124
# Epoch 309/1000... Discriminator Loss: 0.7604... Generator Loss: 2.6936
# Epoch 310/1000... Discriminator Loss: 1.1914... Generator Loss: 1.4453
# Epoch 311/1000... Discriminator Loss: 0.8750... Generator Loss: 2.2971
# Epoch 312/1000... Discriminator Loss: 0.9266... Generator Loss: 2.0584
# Epoch 313/1000... Discriminator Loss: 0.9360... Generator Loss: 2.2695
# Epoch 314/1000... Discriminator Loss: 0.9788... Generator Loss: 1.7728
# Epoch 315/1000... Discriminator Loss: 0.7212... Generator Loss: 2.2993
# Epoch 316/1000... Discriminator Loss: 1.0715... Generator Loss: 2.3218
# Epoch 317/1000... Discriminator Loss: 1.1113... Generator Loss: 2.2012
# Epoch 318/1000... Discriminator Loss: 0.9238... Generator Loss: 2.1331
# Epoch 319/1000... Discriminator Loss: 0.8996... Generator Loss: 2.1902
# Epoch 320/1000... Discriminator Loss: 1.0120... Generator Loss: 1.8458
# Epoch 321/1000... Discriminator Loss: 0.9638... Generator Loss: 1.8584
# Epoch 322/1000... Discriminator Loss: 0.8816... Generator Loss: 2.1886
# Epoch 323/1000... Discriminator Loss: 0.9188... Generator Loss: 2.0869
# Epoch 324/1000... Discriminator Loss: 0.9753... Generator Loss: 1.8126
# Epoch 325/1000... Discriminator Loss: 0.9314... Generator Loss: 2.0670
# Epoch 326/1000... Discriminator Loss: 0.9638... Generator Loss: 2.3368
# Epoch 327/1000... Discriminator Loss: 0.8549... Generator Loss: 2.0204
# Epoch 328/1000... Discriminator Loss: 0.9656... Generator Loss: 2.2164
# Epoch 329/1000... Discriminator Loss: 1.0754... Generator Loss: 1.5714
# Epoch 330/1000... Discriminator Loss: 1.0029... Generator Loss: 1.6403
# Epoch 331/1000... Discriminator Loss: 0.9010... Generator Loss: 2.0931
# Epoch 332/1000... Discriminator Loss: 1.0721... Generator Loss: 1.7126
# Epoch 333/1000... Discriminator Loss: 1.0040... Generator Loss: 1.6993
# Epoch 334/1000... Discriminator Loss: 1.1057... Generator Loss: 1.9310
# Epoch 335/1000... Discriminator Loss: 1.1514... Generator Loss: 1.9691
# Epoch 336/1000... Discriminator Loss: 1.0724... Generator Loss: 1.8819
# Epoch 337/1000... Discriminator Loss: 0.7607... Generator Loss: 2.6226
# Epoch 338/1000... Discriminator Loss: 0.9542... Generator Loss: 1.8370
# Epoch 339/1000... Discriminator Loss: 0.9999... Generator Loss: 2.3291
# Epoch 340/1000... Discriminator Loss: 0.8324... Generator Loss: 2.2020
# Epoch 341/1000... Discriminator Loss: 0.8402... Generator Loss: 2.3096
# Epoch 342/1000... Discriminator Loss: 0.9278... Generator Loss: 2.1920
# Epoch 343/1000... Discriminator Loss: 0.8781... Generator Loss: 2.3046
# Epoch 344/1000... Discriminator Loss: 0.9403... Generator Loss: 2.2811
# Epoch 345/1000... Discriminator Loss: 1.1298... Generator Loss: 2.0791
# Epoch 346/1000... Discriminator Loss: 1.0503... Generator Loss: 1.5566
# Epoch 347/1000... Discriminator Loss: 0.8783... Generator Loss: 2.2698
# Epoch 348/1000... Discriminator Loss: 1.1012... Generator Loss: 1.6831
# Epoch 349/1000... Discriminator Loss: 0.9309... Generator Loss: 1.7433
# Epoch 350/1000... Discriminator Loss: 1.0505... Generator Loss: 1.9968
# Epoch 351/1000... Discriminator Loss: 0.8549... Generator Loss: 2.1228
# Epoch 352/1000... Discriminator Loss: 0.9852... Generator Loss: 1.8623
# Epoch 353/1000... Discriminator Loss: 1.1790... Generator Loss: 2.2054
# Epoch 354/1000... Discriminator Loss: 1.0305... Generator Loss: 1.9944
# Epoch 355/1000... Discriminator Loss: 0.9512... Generator Loss: 1.7317
# Epoch 356/1000... Discriminator Loss: 1.1448... Generator Loss: 1.6638
# Epoch 357/1000... Discriminator Loss: 0.9744... Generator Loss: 1.7099
# Epoch 358/1000... Discriminator Loss: 0.8808... Generator Loss: 2.0852
# Epoch 359/1000... Discriminator Loss: 0.9998... Generator Loss: 1.5888
# Epoch 360/1000... Discriminator Loss: 0.8949... Generator Loss: 2.1638
# Epoch 361/1000... Discriminator Loss: 1.1409... Generator Loss: 1.6085
# Epoch 362/1000... Discriminator Loss: 0.9857... Generator Loss: 2.1305
# Epoch 363/1000... Discriminator Loss: 0.9698... Generator Loss: 2.1568
# Epoch 364/1000... Discriminator Loss: 0.9941... Generator Loss: 2.0444
# Epoch 365/1000... Discriminator Loss: 0.9009... Generator Loss: 1.9085
# Epoch 366/1000... Discriminator Loss: 1.1533... Generator Loss: 1.3479
# Epoch 367/1000... Discriminator Loss: 1.0831... Generator Loss: 1.5133
# Epoch 368/1000... Discriminator Loss: 0.9138... Generator Loss: 1.7487
# Epoch 369/1000... Discriminator Loss: 0.9553... Generator Loss: 1.8073
# Epoch 370/1000... Discriminator Loss: 0.8363... Generator Loss: 1.8556
# Epoch 371/1000... Discriminator Loss: 0.8131... Generator Loss: 2.1952
# Epoch 372/1000... Discriminator Loss: 1.0031... Generator Loss: 1.8946
# Epoch 373/1000... Discriminator Loss: 1.0148... Generator Loss: 1.6716
# Epoch 374/1000... Discriminator Loss: 0.8340... Generator Loss: 2.0199
# Epoch 375/1000... Discriminator Loss: 1.0221... Generator Loss: 1.7222
# Epoch 376/1000... Discriminator Loss: 0.9619... Generator Loss: 2.0091
# Epoch 377/1000... Discriminator Loss: 1.1559... Generator Loss: 1.9829
# Epoch 378/1000... Discriminator Loss: 0.8732... Generator Loss: 1.7331
# Epoch 379/1000... Discriminator Loss: 0.7809... Generator Loss: 2.2757
# Epoch 380/1000... Discriminator Loss: 0.9955... Generator Loss: 1.6595
# Epoch 381/1000... Discriminator Loss: 1.0595... Generator Loss: 1.7832
# Epoch 382/1000... Discriminator Loss: 0.8906... Generator Loss: 1.9419
# Epoch 383/1000... Discriminator Loss: 1.0973... Generator Loss: 1.5935
# Epoch 384/1000... Discriminator Loss: 1.1177... Generator Loss: 1.7523
# Epoch 385/1000... Discriminator Loss: 0.9437... Generator Loss: 1.9847
# Epoch 386/1000... Discriminator Loss: 1.0482... Generator Loss: 2.0864
# Epoch 387/1000... Discriminator Loss: 0.9799... Generator Loss: 2.0256
# Epoch 388/1000... Discriminator Loss: 0.9083... Generator Loss: 1.9986
# Epoch 389/1000... Discriminator Loss: 1.3187... Generator Loss: 1.4681
# Epoch 390/1000... Discriminator Loss: 0.9304... Generator Loss: 1.7532
# Epoch 391/1000... Discriminator Loss: 1.0516... Generator Loss: 1.8710
# Epoch 392/1000... Discriminator Loss: 0.9574... Generator Loss: 2.0262
# Epoch 393/1000... Discriminator Loss: 0.9546... Generator Loss: 1.9117
# Epoch 394/1000... Discriminator Loss: 1.1537... Generator Loss: 1.5202
# Epoch 395/1000... Discriminator Loss: 0.9250... Generator Loss: 2.3593
# Epoch 396/1000... Discriminator Loss: 0.9836... Generator Loss: 1.8706
# Epoch 397/1000... Discriminator Loss: 1.0918... Generator Loss: 1.6193
# Epoch 398/1000... Discriminator Loss: 1.0310... Generator Loss: 1.6950
# Epoch 399/1000... Discriminator Loss: 1.0273... Generator Loss: 1.7644
# Epoch 400/1000... Discriminator Loss: 1.2783... Generator Loss: 1.3060
# Epoch 401/1000... Discriminator Loss: 0.9221... Generator Loss: 2.3589
# Epoch 402/1000... Discriminator Loss: 1.0583... Generator Loss: 1.7510
# Epoch 403/1000... Discriminator Loss: 0.9930... Generator Loss: 2.0110
# Epoch 404/1000... Discriminator Loss: 1.0134... Generator Loss: 1.7009
# Epoch 405/1000... Discriminator Loss: 1.0197... Generator Loss: 1.5677
# Epoch 406/1000... Discriminator Loss: 1.2008... Generator Loss: 1.3836
# Epoch 407/1000... Discriminator Loss: 0.9094... Generator Loss: 2.3807
# Epoch 408/1000... Discriminator Loss: 0.9190... Generator Loss: 1.7527
# Epoch 409/1000... Discriminator Loss: 1.0315... Generator Loss: 1.7663
# Epoch 410/1000... Discriminator Loss: 0.8899... Generator Loss: 2.0744
# Epoch 411/1000... Discriminator Loss: 0.8584... Generator Loss: 2.0607
# Epoch 412/1000... Discriminator Loss: 0.9342... Generator Loss: 2.2637
# Epoch 413/1000... Discriminator Loss: 0.9571... Generator Loss: 1.8529
# Epoch 414/1000... Discriminator Loss: 1.0567... Generator Loss: 1.7366
# Epoch 415/1000... Discriminator Loss: 0.9223... Generator Loss: 2.0119
# Epoch 416/1000... Discriminator Loss: 1.0061... Generator Loss: 1.6954
# Epoch 417/1000... Discriminator Loss: 1.0988... Generator Loss: 1.4718
# Epoch 418/1000... Discriminator Loss: 1.0492... Generator Loss: 1.5495
# Epoch 419/1000... Discriminator Loss: 1.0050... Generator Loss: 1.9559
# Epoch 420/1000... Discriminator Loss: 1.1477... Generator Loss: 2.2334
# Epoch 421/1000... Discriminator Loss: 1.0232... Generator Loss: 1.9958
# Epoch 422/1000... Discriminator Loss: 0.9471... Generator Loss: 2.1757
# Epoch 423/1000... Discriminator Loss: 0.9966... Generator Loss: 1.6253
# Epoch 424/1000... Discriminator Loss: 0.9999... Generator Loss: 2.1158
# Epoch 425/1000... Discriminator Loss: 1.2074... Generator Loss: 1.7117
# Epoch 426/1000... Discriminator Loss: 0.9335... Generator Loss: 1.9437
# Epoch 427/1000... Discriminator Loss: 0.9047... Generator Loss: 2.0327
# Epoch 428/1000... Discriminator Loss: 1.0071... Generator Loss: 1.6874
# Epoch 429/1000... Discriminator Loss: 1.0139... Generator Loss: 1.7836
# Epoch 430/1000... Discriminator Loss: 0.9215... Generator Loss: 1.6728
# Epoch 431/1000... Discriminator Loss: 0.9370... Generator Loss: 1.8048
# Epoch 432/1000... Discriminator Loss: 1.0866... Generator Loss: 1.6180
# Epoch 433/1000... Discriminator Loss: 0.9749... Generator Loss: 1.8419
# Epoch 434/1000... Discriminator Loss: 1.0201... Generator Loss: 2.0219
# Epoch 435/1000... Discriminator Loss: 0.9566... Generator Loss: 1.7531
# Epoch 436/1000... Discriminator Loss: 1.0091... Generator Loss: 1.8293
# Epoch 437/1000... Discriminator Loss: 1.0763... Generator Loss: 1.7239
# Epoch 438/1000... Discriminator Loss: 0.9648... Generator Loss: 1.8342
# Epoch 439/1000... Discriminator Loss: 1.1236... Generator Loss: 1.6142
# Epoch 440/1000... Discriminator Loss: 0.8917... Generator Loss: 1.9736
# Epoch 441/1000... Discriminator Loss: 1.0292... Generator Loss: 1.6165
# Epoch 442/1000... Discriminator Loss: 1.0411... Generator Loss: 1.5754
# Epoch 443/1000... Discriminator Loss: 1.0848... Generator Loss: 1.8166
# Epoch 444/1000... Discriminator Loss: 1.0257... Generator Loss: 2.1626
# Epoch 445/1000... Discriminator Loss: 0.9844... Generator Loss: 2.1240
# Epoch 446/1000... Discriminator Loss: 0.8774... Generator Loss: 2.4533
# Epoch 447/1000... Discriminator Loss: 1.0557... Generator Loss: 1.8657
# Epoch 448/1000... Discriminator Loss: 0.8621... Generator Loss: 2.1906
# Epoch 449/1000... Discriminator Loss: 0.9503... Generator Loss: 2.1909
# Epoch 450/1000... Discriminator Loss: 0.9392... Generator Loss: 2.1086
# Epoch 451/1000... Discriminator Loss: 1.0019... Generator Loss: 1.5539
# Epoch 452/1000... Discriminator Loss: 0.9334... Generator Loss: 1.8351
# Epoch 453/1000... Discriminator Loss: 1.1100... Generator Loss: 1.6535
# Epoch 454/1000... Discriminator Loss: 1.0212... Generator Loss: 1.7970
# Epoch 455/1000... Discriminator Loss: 0.8492... Generator Loss: 2.4341
# Epoch 456/1000... Discriminator Loss: 1.0512... Generator Loss: 2.0526
# Epoch 457/1000... Discriminator Loss: 0.8707... Generator Loss: 2.3196
# Epoch 458/1000... Discriminator Loss: 0.9364... Generator Loss: 1.8222
# Epoch 459/1000... Discriminator Loss: 0.8901... Generator Loss: 1.9570
# Epoch 460/1000... Discriminator Loss: 0.9020... Generator Loss: 1.8686
# Epoch 461/1000... Discriminator Loss: 0.9470... Generator Loss: 1.9690
# Epoch 462/1000... Discriminator Loss: 0.8865... Generator Loss: 2.0253
# Epoch 463/1000... Discriminator Loss: 1.0606... Generator Loss: 1.9319
# Epoch 464/1000... Discriminator Loss: 1.0266... Generator Loss: 1.7672
# Epoch 465/1000... Discriminator Loss: 1.0021... Generator Loss: 1.9438
# Epoch 466/1000... Discriminator Loss: 1.0034... Generator Loss: 1.7320
# Epoch 467/1000... Discriminator Loss: 0.9530... Generator Loss: 1.7027
# Epoch 468/1000... Discriminator Loss: 0.9284... Generator Loss: 1.9599
# Epoch 469/1000... Discriminator Loss: 0.9473... Generator Loss: 2.1012
# Epoch 470/1000... Discriminator Loss: 1.1448... Generator Loss: 1.5967
# Epoch 471/1000... Discriminator Loss: 0.9582... Generator Loss: 2.0838
# Epoch 472/1000... Discriminator Loss: 0.9254... Generator Loss: 1.9058
# Epoch 473/1000... Discriminator Loss: 0.8970... Generator Loss: 1.9226
# Epoch 474/1000... Discriminator Loss: 0.8086... Generator Loss: 2.0510
# Epoch 475/1000... Discriminator Loss: 1.1627... Generator Loss: 1.5347
# Epoch 476/1000... Discriminator Loss: 1.0373... Generator Loss: 1.8742
# Epoch 477/1000... Discriminator Loss: 0.9264... Generator Loss: 1.8708
# Epoch 478/1000... Discriminator Loss: 0.9421... Generator Loss: 2.0606
# Epoch 479/1000... Discriminator Loss: 0.9540... Generator Loss: 1.8305
# Epoch 480/1000... Discriminator Loss: 0.9887... Generator Loss: 1.8672
# Epoch 481/1000... Discriminator Loss: 1.1388... Generator Loss: 2.2178
# Epoch 482/1000... Discriminator Loss: 0.9220... Generator Loss: 2.1385
# Epoch 483/1000... Discriminator Loss: 1.0162... Generator Loss: 1.4571
# Epoch 484/1000... Discriminator Loss: 0.9798... Generator Loss: 2.2155
# Epoch 485/1000... Discriminator Loss: 1.0015... Generator Loss: 1.8217
# Epoch 486/1000... Discriminator Loss: 0.8848... Generator Loss: 2.3035
# Epoch 487/1000... Discriminator Loss: 0.8986... Generator Loss: 2.1822
# Epoch 488/1000... Discriminator Loss: 0.9564... Generator Loss: 1.9895
# Epoch 489/1000... Discriminator Loss: 0.9619... Generator Loss: 1.8235
# Epoch 490/1000... Discriminator Loss: 0.8438... Generator Loss: 2.1793
# Epoch 491/1000... Discriminator Loss: 1.0850... Generator Loss: 2.0197
# Epoch 492/1000... Discriminator Loss: 1.0020... Generator Loss: 2.3129
# Epoch 493/1000... Discriminator Loss: 1.0053... Generator Loss: 1.8091
# Epoch 494/1000... Discriminator Loss: 1.1700... Generator Loss: 1.5587
# Epoch 495/1000... Discriminator Loss: 0.7508... Generator Loss: 2.2148
# Epoch 496/1000... Discriminator Loss: 0.9238... Generator Loss: 2.0906
# Epoch 497/1000... Discriminator Loss: 0.8852... Generator Loss: 2.0379
# Epoch 498/1000... Discriminator Loss: 0.8596... Generator Loss: 2.0555
# Epoch 499/1000... Discriminator Loss: 0.9006... Generator Loss: 1.8525
# Epoch 500/1000... Discriminator Loss: 0.9510... Generator Loss: 1.9216
# Epoch 501/1000... Discriminator Loss: 0.7904... Generator Loss: 2.3437
# Epoch 502/1000... Discriminator Loss: 1.1323... Generator Loss: 1.8186
# Epoch 503/1000... Discriminator Loss: 0.9066... Generator Loss: 1.9885
# Epoch 504/1000... Discriminator Loss: 0.8178... Generator Loss: 2.1252
# Epoch 505/1000... Discriminator Loss: 0.9305... Generator Loss: 2.3029
# Epoch 506/1000... Discriminator Loss: 1.0011... Generator Loss: 1.7897
# Epoch 507/1000... Discriminator Loss: 0.7993... Generator Loss: 2.2864
# Epoch 508/1000... Discriminator Loss: 0.9250... Generator Loss: 2.2001
# Epoch 509/1000... Discriminator Loss: 0.8327... Generator Loss: 1.9950
# Epoch 510/1000... Discriminator Loss: 0.9844... Generator Loss: 1.8503
# Epoch 511/1000... Discriminator Loss: 1.0164... Generator Loss: 2.1295
# Epoch 512/1000... Discriminator Loss: 0.8338... Generator Loss: 1.9587
# Epoch 513/1000... Discriminator Loss: 0.9313... Generator Loss: 2.2711
# Epoch 514/1000... Discriminator Loss: 0.9023... Generator Loss: 2.0315
# Epoch 515/1000... Discriminator Loss: 0.8555... Generator Loss: 1.8306
# Epoch 516/1000... Discriminator Loss: 0.9261... Generator Loss: 2.2968
# Epoch 517/1000... Discriminator Loss: 0.9198... Generator Loss: 1.8638
# Epoch 518/1000... Discriminator Loss: 0.8968... Generator Loss: 2.1378
# Epoch 519/1000... Discriminator Loss: 0.9968... Generator Loss: 1.7566
# Epoch 520/1000... Discriminator Loss: 0.9170... Generator Loss: 2.1031
# Epoch 521/1000... Discriminator Loss: 0.9631... Generator Loss: 2.2543
# Epoch 522/1000... Discriminator Loss: 0.8457... Generator Loss: 2.2577
# Epoch 523/1000... Discriminator Loss: 0.9756... Generator Loss: 1.8273
# Epoch 524/1000... Discriminator Loss: 0.9297... Generator Loss: 2.3161
# Epoch 525/1000... Discriminator Loss: 0.9002... Generator Loss: 2.0380
# Epoch 526/1000... Discriminator Loss: 0.9983... Generator Loss: 1.7084
# Epoch 527/1000... Discriminator Loss: 0.8374... Generator Loss: 2.1106
# Epoch 528/1000... Discriminator Loss: 1.0763... Generator Loss: 2.0029
# Epoch 529/1000... Discriminator Loss: 0.9779... Generator Loss: 1.9484
# Epoch 530/1000... Discriminator Loss: 0.8578... Generator Loss: 2.2123
# Epoch 531/1000... Discriminator Loss: 0.8428... Generator Loss: 2.1124
# Epoch 532/1000... Discriminator Loss: 0.9916... Generator Loss: 1.8863
# Epoch 533/1000... Discriminator Loss: 0.8031... Generator Loss: 2.8380
# Epoch 534/1000... Discriminator Loss: 0.7875... Generator Loss: 2.5060
# Epoch 535/1000... Discriminator Loss: 0.9353... Generator Loss: 2.2875
# Epoch 536/1000... Discriminator Loss: 0.8680... Generator Loss: 1.8990
# Epoch 537/1000... Discriminator Loss: 0.9458... Generator Loss: 1.7296
# Epoch 538/1000... Discriminator Loss: 0.9273... Generator Loss: 2.1126
# Epoch 539/1000... Discriminator Loss: 0.9373... Generator Loss: 1.7617
# Epoch 540/1000... Discriminator Loss: 0.7706... Generator Loss: 2.4743
# Epoch 541/1000... Discriminator Loss: 0.9527... Generator Loss: 1.8750
# Epoch 542/1000... Discriminator Loss: 0.8276... Generator Loss: 1.9386
# Epoch 543/1000... Discriminator Loss: 1.0355... Generator Loss: 2.0704
# Epoch 544/1000... Discriminator Loss: 0.9380... Generator Loss: 2.1765
# Epoch 545/1000... Discriminator Loss: 0.9183... Generator Loss: 2.4522
# Epoch 546/1000... Discriminator Loss: 1.0022... Generator Loss: 1.7190
# Epoch 547/1000... Discriminator Loss: 0.9206... Generator Loss: 2.0766
# Epoch 548/1000... Discriminator Loss: 0.8864... Generator Loss: 1.8342
# Epoch 549/1000... Discriminator Loss: 0.8547... Generator Loss: 2.0810
# Epoch 550/1000... Discriminator Loss: 0.8578... Generator Loss: 2.0138
# Epoch 551/1000... Discriminator Loss: 0.7812... Generator Loss: 2.3297
# Epoch 552/1000... Discriminator Loss: 0.8746... Generator Loss: 2.1733
# Epoch 553/1000... Discriminator Loss: 0.9455... Generator Loss: 1.7761
# Epoch 554/1000... Discriminator Loss: 0.9252... Generator Loss: 2.0413
# Epoch 555/1000... Discriminator Loss: 0.9644... Generator Loss: 2.1519
# Epoch 556/1000... Discriminator Loss: 0.8862... Generator Loss: 2.3261
# Epoch 557/1000... Discriminator Loss: 1.0822... Generator Loss: 1.8761
# Epoch 558/1000... Discriminator Loss: 0.9857... Generator Loss: 2.0165
# Epoch 559/1000... Discriminator Loss: 0.9074... Generator Loss: 2.1507
# Epoch 560/1000... Discriminator Loss: 1.0764... Generator Loss: 1.8551
# Epoch 561/1000... Discriminator Loss: 0.9019... Generator Loss: 1.7917
# Epoch 562/1000... Discriminator Loss: 0.9020... Generator Loss: 2.4782
# Epoch 563/1000... Discriminator Loss: 0.9226... Generator Loss: 2.4341
# Epoch 564/1000... Discriminator Loss: 0.9022... Generator Loss: 2.0970
# Epoch 565/1000... Discriminator Loss: 1.0464... Generator Loss: 2.0287
# Epoch 566/1000... Discriminator Loss: 0.9726... Generator Loss: 1.9098
# Epoch 567/1000... Discriminator Loss: 0.9469... Generator Loss: 2.0378
# Epoch 568/1000... Discriminator Loss: 1.0301... Generator Loss: 2.0145
# Epoch 569/1000... Discriminator Loss: 0.9814... Generator Loss: 2.3487
# Epoch 570/1000... Discriminator Loss: 1.1176... Generator Loss: 1.8763
# Epoch 571/1000... Discriminator Loss: 0.9207... Generator Loss: 1.9906
# Epoch 572/1000... Discriminator Loss: 1.0076... Generator Loss: 2.1997
# Epoch 573/1000... Discriminator Loss: 1.0377... Generator Loss: 1.5665
# Epoch 574/1000... Discriminator Loss: 0.9355... Generator Loss: 2.0593
# Epoch 575/1000... Discriminator Loss: 1.1184... Generator Loss: 1.5807
# Epoch 576/1000... Discriminator Loss: 0.8796... Generator Loss: 2.3029
# Epoch 577/1000... Discriminator Loss: 1.0649... Generator Loss: 1.7744
# Epoch 578/1000... Discriminator Loss: 0.8520... Generator Loss: 2.1173
# Epoch 579/1000... Discriminator Loss: 0.8827... Generator Loss: 2.1283
# Epoch 580/1000... Discriminator Loss: 1.0351... Generator Loss: 1.7105
# Epoch 581/1000... Discriminator Loss: 0.8982... Generator Loss: 1.9869
# Epoch 582/1000... Discriminator Loss: 0.8308... Generator Loss: 2.2966
# Epoch 583/1000... Discriminator Loss: 1.0361... Generator Loss: 1.6532
# Epoch 584/1000... Discriminator Loss: 0.8223... Generator Loss: 2.2848
# Epoch 585/1000... Discriminator Loss: 1.0818... Generator Loss: 2.9753
# Epoch 586/1000... Discriminator Loss: 0.9047... Generator Loss: 2.0242
# Epoch 587/1000... Discriminator Loss: 0.8303... Generator Loss: 2.3843
# Epoch 588/1000... Discriminator Loss: 0.9459... Generator Loss: 1.7162
# Epoch 589/1000... Discriminator Loss: 1.0060... Generator Loss: 2.3584
# Epoch 590/1000... Discriminator Loss: 0.9791... Generator Loss: 2.1181
# Epoch 591/1000... Discriminator Loss: 0.8490... Generator Loss: 2.2378
# Epoch 592/1000... Discriminator Loss: 0.8045... Generator Loss: 2.1851
# Epoch 593/1000... Discriminator Loss: 0.8733... Generator Loss: 1.8376
# Epoch 594/1000... Discriminator Loss: 0.9267... Generator Loss: 2.2635
# Epoch 595/1000... Discriminator Loss: 0.8168... Generator Loss: 2.6410
# Epoch 596/1000... Discriminator Loss: 1.1274... Generator Loss: 2.1271
# Epoch 597/1000... Discriminator Loss: 0.8537... Generator Loss: 2.1906
# Epoch 598/1000... Discriminator Loss: 0.8964... Generator Loss: 2.0428
# Epoch 599/1000... Discriminator Loss: 0.8956... Generator Loss: 2.2213
# Epoch 600/1000... Discriminator Loss: 1.1291... Generator Loss: 1.5866
# Epoch 601/1000... Discriminator Loss: 0.8819... Generator Loss: 2.3895
# Epoch 602/1000... Discriminator Loss: 0.8680... Generator Loss: 1.9554
# Epoch 603/1000... Discriminator Loss: 1.1016... Generator Loss: 1.9096
# Epoch 604/1000... Discriminator Loss: 1.1599... Generator Loss: 1.6091
# Epoch 605/1000... Discriminator Loss: 0.8685... Generator Loss: 1.9969
# Epoch 606/1000... Discriminator Loss: 0.9366... Generator Loss: 2.4124
# Epoch 607/1000... Discriminator Loss: 0.9616... Generator Loss: 1.8609
# Epoch 608/1000... Discriminator Loss: 0.9394... Generator Loss: 2.5082
# Epoch 609/1000... Discriminator Loss: 0.9702... Generator Loss: 1.6497
# Epoch 610/1000... Discriminator Loss: 1.0464... Generator Loss: 1.8959
# Epoch 611/1000... Discriminator Loss: 0.8750... Generator Loss: 2.5030
# Epoch 612/1000... Discriminator Loss: 0.8896... Generator Loss: 1.8418
# Epoch 613/1000... Discriminator Loss: 0.9273... Generator Loss: 1.8713
# Epoch 614/1000... Discriminator Loss: 1.0301... Generator Loss: 1.9266
# Epoch 615/1000... Discriminator Loss: 1.0379... Generator Loss: 1.5917
# Epoch 616/1000... Discriminator Loss: 0.9637... Generator Loss: 2.3119
# Epoch 617/1000... Discriminator Loss: 0.9683... Generator Loss: 2.1807
# Epoch 618/1000... Discriminator Loss: 1.0413... Generator Loss: 2.1761
# Epoch 619/1000... Discriminator Loss: 0.8339... Generator Loss: 2.3445
# Epoch 620/1000... Discriminator Loss: 0.8734... Generator Loss: 2.3136
# Epoch 621/1000... Discriminator Loss: 0.9798... Generator Loss: 1.8959
# Epoch 622/1000... Discriminator Loss: 0.9403... Generator Loss: 1.9700
# Epoch 623/1000... Discriminator Loss: 1.1198... Generator Loss: 1.7600
# Epoch 624/1000... Discriminator Loss: 0.9085... Generator Loss: 2.2811
# Epoch 625/1000... Discriminator Loss: 0.9107... Generator Loss: 1.8339
# Epoch 626/1000... Discriminator Loss: 0.9880... Generator Loss: 1.8172
# Epoch 627/1000... Discriminator Loss: 1.0200... Generator Loss: 2.1725
# Epoch 628/1000... Discriminator Loss: 0.9292... Generator Loss: 1.9263
# Epoch 629/1000... Discriminator Loss: 0.8815... Generator Loss: 1.9985
# Epoch 630/1000... Discriminator Loss: 1.0240... Generator Loss: 2.1982
# Epoch 631/1000... Discriminator Loss: 0.8596... Generator Loss: 2.1454
# Epoch 632/1000... Discriminator Loss: 0.8688... Generator Loss: 2.0888
# Epoch 633/1000... Discriminator Loss: 0.8467... Generator Loss: 2.3722
# Epoch 634/1000... Discriminator Loss: 0.8033... Generator Loss: 2.3754
# Epoch 635/1000... Discriminator Loss: 0.9117... Generator Loss: 2.1481
# Epoch 636/1000... Discriminator Loss: 0.9466... Generator Loss: 2.0788
# Epoch 637/1000... Discriminator Loss: 0.9374... Generator Loss: 1.8852
# Epoch 638/1000... Discriminator Loss: 0.8928... Generator Loss: 2.0744
# Epoch 639/1000... Discriminator Loss: 1.0711... Generator Loss: 1.7605
# Epoch 640/1000... Discriminator Loss: 0.9685... Generator Loss: 1.9016
# Epoch 641/1000... Discriminator Loss: 0.9796... Generator Loss: 2.2561
# Epoch 642/1000... Discriminator Loss: 0.9335... Generator Loss: 1.9612
# Epoch 643/1000... Discriminator Loss: 0.8574... Generator Loss: 2.2333
# Epoch 644/1000... Discriminator Loss: 1.0727... Generator Loss: 1.9107
# Epoch 645/1000... Discriminator Loss: 0.8351... Generator Loss: 2.1884
# Epoch 646/1000... Discriminator Loss: 0.9167... Generator Loss: 1.9268
# Epoch 647/1000... Discriminator Loss: 0.9402... Generator Loss: 1.8011
# Epoch 648/1000... Discriminator Loss: 1.0247... Generator Loss: 1.8753
# Epoch 649/1000... Discriminator Loss: 1.0087... Generator Loss: 2.1071
# Epoch 650/1000... Discriminator Loss: 0.9165... Generator Loss: 2.0055
# Epoch 651/1000... Discriminator Loss: 0.9455... Generator Loss: 2.0566
# Epoch 652/1000... Discriminator Loss: 0.9490... Generator Loss: 1.7631
# Epoch 653/1000... Discriminator Loss: 0.8913... Generator Loss: 2.1736
# Epoch 654/1000... Discriminator Loss: 0.8637... Generator Loss: 1.9689
# Epoch 655/1000... Discriminator Loss: 0.8614... Generator Loss: 2.3299
# Epoch 656/1000... Discriminator Loss: 0.9452... Generator Loss: 2.2916
# Epoch 657/1000... Discriminator Loss: 1.1183... Generator Loss: 1.7528
# Epoch 658/1000... Discriminator Loss: 1.0277... Generator Loss: 1.7081
# Epoch 659/1000... Discriminator Loss: 0.8998... Generator Loss: 2.4885
# Epoch 660/1000... Discriminator Loss: 0.9786... Generator Loss: 1.7048
# Epoch 661/1000... Discriminator Loss: 0.8774... Generator Loss: 1.9503
# Epoch 662/1000... Discriminator Loss: 1.0987... Generator Loss: 1.8245
# Epoch 663/1000... Discriminator Loss: 0.9340... Generator Loss: 1.9817
# Epoch 664/1000... Discriminator Loss: 0.9814... Generator Loss: 1.9725
# Epoch 665/1000... Discriminator Loss: 0.9349... Generator Loss: 1.8543
# Epoch 666/1000... Discriminator Loss: 0.9230... Generator Loss: 1.9345
# Epoch 667/1000... Discriminator Loss: 0.9127... Generator Loss: 2.3265
# Epoch 668/1000... Discriminator Loss: 0.9145... Generator Loss: 2.0365
# Epoch 669/1000... Discriminator Loss: 0.8877... Generator Loss: 2.3767
# Epoch 670/1000... Discriminator Loss: 0.8866... Generator Loss: 2.6372
# Epoch 671/1000... Discriminator Loss: 0.9561... Generator Loss: 2.1428
# Epoch 672/1000... Discriminator Loss: 0.9627... Generator Loss: 2.1302
# Epoch 673/1000... Discriminator Loss: 0.9538... Generator Loss: 2.2554
# Epoch 674/1000... Discriminator Loss: 0.8666... Generator Loss: 1.9270
# Epoch 675/1000... Discriminator Loss: 0.8628... Generator Loss: 2.0913
# Epoch 676/1000... Discriminator Loss: 0.7779... Generator Loss: 2.4343
# Epoch 677/1000... Discriminator Loss: 0.8156... Generator Loss: 1.9539
# ...
# Epoch 776/1000... Discriminator Loss: 0.9770... Generator Loss: 2.0153
# Epoch 777/1000... Discriminator Loss: 0.9871... Generator Loss: 1.7528
# Epoch 778/1000... Discriminator Loss: 0.8999... Generator Loss: 2.0315
# Epoch 779/1000... Discriminator Loss: 0.8512... Generator Loss: 1.9841
# Epoch 780/1000... Discriminator Loss: 0.8513... Generator Loss: 2.1564
# Epoch 781/1000... Discriminator Loss: 0.8156... Generator Loss: 2.2131
# Epoch 782/1000... Discriminator Loss: 0.9137... Generator Loss: 2.4623
# Epoch 783/1000... Discriminator Loss: 0.9203... Generator Loss: 1.7831
# Epoch 784/1000... Discriminator Loss: 0.8476... Generator Loss: 2.1102
# Epoch 785/1000... Discriminator Loss: 0.9445... Generator Loss: 1.9533
# Epoch 786/1000... Discriminator Loss: 1.0336... Generator Loss: 1.8445
# Epoch 787/1000... Discriminator Loss: 0.9759... Generator Loss: 1.8061
# Epoch 788/1000... Discriminator Loss: 1.0083... Generator Loss: 1.7917
# Epoch 789/1000... Discriminator Loss: 0.8854... Generator Loss: 2.1064
# Epoch 790/1000... Discriminator Loss: 0.9328... Generator Loss: 1.9122
# Epoch 791/1000... Discriminator Loss: 1.0176... Generator Loss: 2.5103
# Epoch 792/1000... Discriminator Loss: 1.0131... Generator Loss: 2.3798
# Epoch 793/1000... Discriminator Loss: 1.0018... Generator Loss: 2.2812
# Epoch 794/1000... Discriminator Loss: 0.9476... Generator Loss: 1.9252
# Epoch 795/1000... Discriminator Loss: 1.1143... Generator Loss: 1.7192
# Epoch 796/1000... Discriminator Loss: 0.9450... Generator Loss: 1.9564
# Epoch 797/1000... Discriminator Loss: 0.9741... Generator Loss: 2.2425
# Epoch 798/1000... Discriminator Loss: 1.0313... Generator Loss: 1.7969
# Epoch 799/1000... Discriminator Loss: 0.9035... Generator Loss: 2.1236
# Epoch 800/1000... Discriminator Loss: 0.9025... Generator Loss: 2.3277
# Epoch 801/1000... Discriminator Loss: 0.9651... Generator Loss: 2.0657
# Epoch 802/1000... Discriminator Loss: 0.9505... Generator Loss: 2.0805
# Epoch 803/1000... Discriminator Loss: 0.9790... Generator Loss: 1.9495
# Epoch 804/1000... Discriminator Loss: 0.9106... Generator Loss: 1.8330
# Epoch 805/1000... Discriminator Loss: 0.8607... Generator Loss: 2.2790
# Epoch 806/1000... Discriminator Loss: 0.8232... Generator Loss: 2.2878
# Epoch 807/1000... Discriminator Loss: 0.8280... Generator Loss: 2.3604
# Epoch 808/1000... Discriminator Loss: 0.8844... Generator Loss: 2.0247
# Epoch 809/1000... Discriminator Loss: 0.8909... Generator Loss: 2.1033
# Epoch 810/1000... Discriminator Loss: 0.8201... Generator Loss: 1.8568
# Epoch 811/1000... Discriminator Loss: 1.0382... Generator Loss: 1.8350
# Epoch 812/1000... Discriminator Loss: 0.9573... Generator Loss: 1.9704
# Epoch 813/1000... Discriminator Loss: 1.0252... Generator Loss: 1.8907
# Epoch 814/1000... Discriminator Loss: 0.9302... Generator Loss: 2.2580
# Epoch 815/1000... Discriminator Loss: 1.0291... Generator Loss: 2.5803
# Epoch 816/1000... Discriminator Loss: 0.9750... Generator Loss: 2.0647
# Epoch 817/1000... Discriminator Loss: 0.9828... Generator Loss: 1.7945
# Epoch 818/1000... Discriminator Loss: 0.9169... Generator Loss: 2.0001
# Epoch 819/1000... Discriminator Loss: 0.9082... Generator Loss: 2.3119
# Epoch 820/1000... Discriminator Loss: 0.8942... Generator Loss: 2.3162
# Epoch 821/1000... Discriminator Loss: 1.1045... Generator Loss: 1.8776
# Epoch 822/1000... Discriminator Loss: 1.0469... Generator Loss: 1.6961
# Epoch 823/1000... Discriminator Loss: 1.1524... Generator Loss: 1.9458
# Epoch 824/1000... Discriminator Loss: 0.9215... Generator Loss: 1.8724
# Epoch 825/1000... Discriminator Loss: 0.9237... Generator Loss: 2.1816
# Epoch 826/1000... Discriminator Loss: 0.9243... Generator Loss: 1.9700
# Epoch 827/1000... Discriminator Loss: 0.8619... Generator Loss: 1.7672
# Epoch 828/1000... Discriminator Loss: 1.0044... Generator Loss: 1.5329
# Epoch 829/1000... Discriminator Loss: 0.8417... Generator Loss: 2.0285
# Epoch 830/1000... Discriminator Loss: 0.9786... Generator Loss: 1.6892
# Epoch 831/1000... Discriminator Loss: 0.9426... Generator Loss: 1.7081
# Epoch 832/1000... Discriminator Loss: 0.9120... Generator Loss: 1.9786
# Epoch 833/1000... Discriminator Loss: 1.0310... Generator Loss: 2.2581
# Epoch 834/1000... Discriminator Loss: 0.8833... Generator Loss: 2.2517
# Epoch 835/1000... Discriminator Loss: 0.8867... Generator Loss: 2.1714
# Epoch 836/1000... Discriminator Loss: 1.1289... Generator Loss: 1.4981
# Epoch 837/1000... Discriminator Loss: 1.0442... Generator Loss: 2.2133
# Epoch 838/1000... Discriminator Loss: 0.9493... Generator Loss: 2.2152
# Epoch 839/1000... Discriminator Loss: 0.9497... Generator Loss: 2.1157
# Epoch 840/1000... Discriminator Loss: 0.8978... Generator Loss: 1.8516
# Epoch 841/1000... Discriminator Loss: 0.9497... Generator Loss: 1.8475
# Epoch 842/1000... Discriminator Loss: 0.9495... Generator Loss: 2.2050
# Epoch 843/1000... Discriminator Loss: 1.1380... Generator Loss: 1.4552
# Epoch 844/1000... Discriminator Loss: 0.9797... Generator Loss: 1.7954
# Epoch 845/1000... Discriminator Loss: 0.9819... Generator Loss: 1.6414
# Epoch 846/1000... Discriminator Loss: 0.9275... Generator Loss: 1.7363
# Epoch 847/1000... Discriminator Loss: 0.9291... Generator Loss: 1.6720
# Epoch 848/1000... Discriminator Loss: 1.0820... Generator Loss: 1.7999
# Epoch 849/1000... Discriminator Loss: 0.9205... Generator Loss: 1.8540
# Epoch 850/1000... Discriminator Loss: 0.9249... Generator Loss: 1.7565
# Epoch 851/1000... Discriminator Loss: 0.7899... Generator Loss: 2.5371
# Epoch 852/1000... Discriminator Loss: 0.9208... Generator Loss: 2.2140
# Epoch 853/1000... Discriminator Loss: 1.0173... Generator Loss: 2.0380
# Epoch 854/1000... Discriminator Loss: 1.0103... Generator Loss: 1.6859
# Epoch 855/1000... Discriminator Loss: 0.8755... Generator Loss: 1.9300
# Epoch 856/1000... Discriminator Loss: 0.9280... Generator Loss: 1.7813
# Epoch 857/1000... Discriminator Loss: 0.8638... Generator Loss: 1.9541
# Epoch 858/1000... Discriminator Loss: 1.0914... Generator Loss: 1.9548
# Epoch 859/1000... Discriminator Loss: 0.8738... Generator Loss: 2.0955
# Epoch 860/1000... Discriminator Loss: 1.0956... Generator Loss: 2.0041
# Epoch 861/1000... Discriminator Loss: 0.9445... Generator Loss: 1.9921
# Epoch 862/1000... Discriminator Loss: 1.0061... Generator Loss: 2.3187
# Epoch 863/1000... Discriminator Loss: 0.9595... Generator Loss: 2.4540
# Epoch 864/1000... Discriminator Loss: 0.9521... Generator Loss: 2.0476
# Epoch 865/1000... Discriminator Loss: 0.9001... Generator Loss: 1.9534
# Epoch 866/1000... Discriminator Loss: 0.9460... Generator Loss: 1.7049
# Epoch 867/1000... Discriminator Loss: 0.9532... Generator Loss: 2.0404
# Epoch 868/1000... Discriminator Loss: 1.0037... Generator Loss: 1.6466
# Epoch 869/1000... Discriminator Loss: 0.8764... Generator Loss: 1.9175
# Epoch 870/1000... Discriminator Loss: 0.8516... Generator Loss: 1.9153
# Epoch 871/1000... Discriminator Loss: 0.9296... Generator Loss: 1.9770
# Epoch 872/1000... Discriminator Loss: 0.9128... Generator Loss: 1.8103
# Epoch 873/1000... Discriminator Loss: 0.9377... Generator Loss: 2.0169
# Epoch 874/1000... Discriminator Loss: 0.9176... Generator Loss: 1.8369
# Epoch 875/1000... Discriminator Loss: 1.1879... Generator Loss: 1.7201
# Epoch 876/1000... Discriminator Loss: 0.9170... Generator Loss: 1.9206
# Epoch 877/1000... Discriminator Loss: 1.1199... Generator Loss: 1.9836
# Epoch 878/1000... Discriminator Loss: 0.9859... Generator Loss: 1.8752
# Epoch 879/1000... Discriminator Loss: 1.0506... Generator Loss: 1.6834
# Epoch 880/1000... Discriminator Loss: 0.9403... Generator Loss: 1.8220
# Epoch 881/1000... Discriminator Loss: 0.9340... Generator Loss: 1.7092
# Epoch 882/1000... Discriminator Loss: 0.9708... Generator Loss: 2.0475
# Epoch 883/1000... Discriminator Loss: 0.9494... Generator Loss: 2.0918
# Epoch 884/1000... Discriminator Loss: 1.0416... Generator Loss: 1.9024
# Epoch 885/1000... Discriminator Loss: 0.8905... Generator Loss: 2.2362
# Epoch 886/1000... Discriminator Loss: 0.9412... Generator Loss: 1.8008
# Epoch 887/1000... Discriminator Loss: 1.0770... Generator Loss: 2.1039
# Epoch 888/1000... Discriminator Loss: 0.9290... Generator Loss: 2.2024
# Epoch 889/1000... Discriminator Loss: 0.9346... Generator Loss: 2.1763
# Epoch 890/1000... Discriminator Loss: 0.9483... Generator Loss: 1.9596
# Epoch 891/1000... Discriminator Loss: 0.8993... Generator Loss: 1.9340
# Epoch 892/1000... Discriminator Loss: 0.9533... Generator Loss: 1.9983
# Epoch 893/1000... Discriminator Loss: 0.9514... Generator Loss: 1.8585
# Epoch 894/1000... Discriminator Loss: 0.9452... Generator Loss: 2.1842
# Epoch 895/1000... Discriminator Loss: 0.9043... Generator Loss: 2.5672
# Epoch 896/1000... Discriminator Loss: 0.9674... Generator Loss: 1.8659
# Epoch 897/1000... Discriminator Loss: 0.8499... Generator Loss: 2.2473
# Epoch 898/1000... Discriminator Loss: 0.9596... Generator Loss: 2.0746
# Epoch 899/1000... Discriminator Loss: 1.0878... Generator Loss: 1.6868
# Epoch 900/1000... Discriminator Loss: 0.8959... Generator Loss: 2.1341
# Epoch 901/1000... Discriminator Loss: 0.9817... Generator Loss: 1.7481
# Epoch 902/1000... Discriminator Loss: 0.9788... Generator Loss: 1.7707
# Epoch 903/1000... Discriminator Loss: 0.9616... Generator Loss: 2.3471
# Epoch 904/1000... Discriminator Loss: 0.8214... Generator Loss: 2.2495
# Epoch 905/1000... Discriminator Loss: 0.9134... Generator Loss: 1.8499
# Epoch 906/1000... Discriminator Loss: 0.9528... Generator Loss: 1.8460
# Epoch 907/1000... Discriminator Loss: 0.9097... Generator Loss: 2.1093
# Epoch 908/1000... Discriminator Loss: 1.0209... Generator Loss: 1.5372
# Epoch 909/1000... Discriminator Loss: 0.9643... Generator Loss: 1.8513
# Epoch 910/1000... Discriminator Loss: 0.9494... Generator Loss: 1.8836
# Epoch 911/1000... Discriminator Loss: 0.9727... Generator Loss: 1.7992
# Epoch 912/1000... Discriminator Loss: 0.9559... Generator Loss: 2.1161
# Epoch 913/1000... Discriminator Loss: 0.8451... Generator Loss: 2.4115
# Epoch 914/1000... Discriminator Loss: 1.0069... Generator Loss: 1.8544
# Epoch 915/1000... Discriminator Loss: 0.9893... Generator Loss: 2.1791
# Epoch 916/1000... Discriminator Loss: 0.9243... Generator Loss: 2.0884
# Epoch 917/1000... Discriminator Loss: 1.1383... Generator Loss: 1.7948
# Epoch 918/1000... Discriminator Loss: 0.9332... Generator Loss: 2.0484
# Epoch 919/1000... Discriminator Loss: 0.7818... Generator Loss: 2.1063
# Epoch 920/1000... Discriminator Loss: 0.8871... Generator Loss: 1.8378
# Epoch 921/1000... Discriminator Loss: 1.1491... Generator Loss: 1.6445
# Epoch 922/1000... Discriminator Loss: 1.0037... Generator Loss: 2.1408
# Epoch 923/1000... Discriminator Loss: 0.9178... Generator Loss: 1.8814
# Epoch 924/1000... Discriminator Loss: 0.9506... Generator Loss: 1.9292
# Epoch 925/1000... Discriminator Loss: 0.9445... Generator Loss: 1.7696
# Epoch 926/1000... Discriminator Loss: 0.9070... Generator Loss: 1.6929
# Epoch 927/1000... Discriminator Loss: 1.0497... Generator Loss: 1.8309
# Epoch 928/1000... Discriminator Loss: 1.0330... Generator Loss: 2.0663
# Epoch 929/1000... Discriminator Loss: 0.9298... Generator Loss: 1.6404
# Epoch 930/1000... Discriminator Loss: 1.0129... Generator Loss: 1.9959
# Epoch 931/1000... Discriminator Loss: 0.9684... Generator Loss: 2.0524
# Epoch 932/1000... Discriminator Loss: 0.9903... Generator Loss: 1.9537
# Epoch 933/1000... Discriminator Loss: 0.8368... Generator Loss: 1.9545
# Epoch 934/1000... Discriminator Loss: 1.0221... Generator Loss: 1.7789
# Epoch 935/1000... Discriminator Loss: 0.9043... Generator Loss: 2.0163
# Epoch 936/1000... Discriminator Loss: 0.8559... Generator Loss: 2.4004
# Epoch 937/1000... Discriminator Loss: 0.9716... Generator Loss: 1.7965
# Epoch 938/1000... Discriminator Loss: 0.9382... Generator Loss: 1.8981
# Epoch 939/1000... Discriminator Loss: 0.8424... Generator Loss: 1.9194
# Epoch 940/1000... Discriminator Loss: 0.8966... Generator Loss: 1.9688
# Epoch 941/1000... Discriminator Loss: 0.9717... Generator Loss: 1.8823
# Epoch 942/1000... Discriminator Loss: 1.0519... Generator Loss: 1.8158
# Epoch 943/1000... Discriminator Loss: 0.9097... Generator Loss: 1.9662
# Epoch 944/1000... Discriminator Loss: 0.9627... Generator Loss: 1.4858
# Epoch 945/1000... Discriminator Loss: 0.9464... Generator Loss: 1.6074
# Epoch 946/1000... Discriminator Loss: 0.9581... Generator Loss: 2.4439
# Epoch 947/1000... Discriminator Loss: 0.9678... Generator Loss: 1.6711
# Epoch 948/1000... Discriminator Loss: 0.9501... Generator Loss: 2.1429
# Epoch 949/1000... Discriminator Loss: 0.9345... Generator Loss: 2.0848
# Epoch 950/1000... Discriminator Loss: 0.8367... Generator Loss: 2.2445
# Epoch 951/1000... Discriminator Loss: 1.0244... Generator Loss: 1.6126
# Epoch 952/1000... Discriminator Loss: 0.9643... Generator Loss: 1.9378
# Epoch 953/1000... Discriminator Loss: 1.0007... Generator Loss: 2.5153
# Epoch 954/1000... Discriminator Loss: 0.9358... Generator Loss: 1.9195
# Epoch 955/1000... Discriminator Loss: 0.8558... Generator Loss: 1.9193
# Epoch 956/1000... Discriminator Loss: 1.0168... Generator Loss: 1.8387
# Epoch 957/1000... Discriminator Loss: 0.8542... Generator Loss: 2.1885
# Epoch 958/1000... Discriminator Loss: 0.8233... Generator Loss: 2.2511
# Epoch 959/1000... Discriminator Loss: 1.0017... Generator Loss: 1.6624
# Epoch 960/1000... Discriminator Loss: 0.9133... Generator Loss: 1.9961
# Epoch 961/1000... Discriminator Loss: 0.9649... Generator Loss: 2.1277
# Epoch 962/1000... Discriminator Loss: 0.9316... Generator Loss: 1.8222
# Epoch 963/1000... Discriminator Loss: 1.0262... Generator Loss: 1.7185
# Epoch 964/1000... Discriminator Loss: 0.9399... Generator Loss: 1.8408
# Epoch 965/1000... Discriminator Loss: 0.9760... Generator Loss: 1.7878
# Epoch 966/1000... Discriminator Loss: 0.8249... Generator Loss: 2.2421
# Epoch 967/1000... Discriminator Loss: 0.9616... Generator Loss: 1.8836
# Epoch 968/1000... Discriminator Loss: 0.9463... Generator Loss: 2.0718
# Epoch 969/1000... Discriminator Loss: 0.9822... Generator Loss: 1.6968
# Epoch 970/1000... Discriminator Loss: 0.8402... Generator Loss: 2.1770
# Epoch 971/1000... Discriminator Loss: 0.8475... Generator Loss: 2.0493
# Epoch 972/1000... Discriminator Loss: 0.8922... Generator Loss: 1.9774
# Epoch 973/1000... Discriminator Loss: 0.9290... Generator Loss: 1.9542
# Epoch 974/1000... Discriminator Loss: 0.9261... Generator Loss: 1.6611
# Epoch 975/1000... Discriminator Loss: 0.8114... Generator Loss: 1.9918
# Epoch 976/1000... Discriminator Loss: 1.0045... Generator Loss: 2.2131
# Epoch 977/1000... Discriminator Loss: 1.0000... Generator Loss: 1.7326
# Epoch 978/1000... Discriminator Loss: 0.9180... Generator Loss: 1.8336
# Epoch 979/1000... Discriminator Loss: 0.8979... Generator Loss: 2.0500
# Epoch 980/1000... Discriminator Loss: 0.9128... Generator Loss: 1.9628
# Epoch 981/1000... Discriminator Loss: 1.0873... Generator Loss: 1.9491
# Epoch 982/1000... Discriminator Loss: 0.9836... Generator Loss: 2.0444
# Epoch 983/1000... Discriminator Loss: 0.8791... Generator Loss: 1.7969
# Epoch 984/1000... Discriminator Loss: 0.9512... Generator Loss: 1.7373
# Epoch 985/1000... Discriminator Loss: 0.9464... Generator Loss: 2.3695
# Epoch 986/1000... Discriminator Loss: 1.0322... Generator Loss: 1.6370
# Epoch 987/1000... Discriminator Loss: 0.8882... Generator Loss: 1.7520
# Epoch 988/1000... Discriminator Loss: 0.8297... Generator Loss: 2.2480
# Epoch 989/1000... Discriminator Loss: 0.9745... Generator Loss: 1.8892
# Epoch 990/1000... Discriminator Loss: 0.8501... Generator Loss: 1.9514
# Epoch 991/1000... Discriminator Loss: 0.9825... Generator Loss: 1.7181
# Epoch 992/1000... Discriminator Loss: 1.0102... Generator Loss: 2.3632
# Epoch 993/1000... Discriminator Loss: 0.8607... Generator Loss: 2.4855
# Epoch 994/1000... Discriminator Loss: 0.9083... Generator Loss: 2.0011
# Epoch 995/1000... Discriminator Loss: 0.8758... Generator Loss: 2.3474
# Epoch 996/1000... Discriminator Loss: 0.8234... Generator Loss: 2.3231
# Epoch 997/1000... Discriminator Loss: 0.9551... Generator Loss: 1.9681
# Epoch 998/1000... Discriminator Loss: 1.0758... Generator Loss: 2.0606
# Epoch 999/1000... Discriminator Loss: 1.0148... Generator Loss: 1.5415
# Epoch 1000/1000... Discriminator Loss: 0.9933... Generator Loss: 1.5884

# %% [markdown]
# ## Training loss
#
# Here we'll check out the training losses for the generator and discriminator.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at images taken while training.

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 5, 7, 3, 0, 9. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs. With bonus optical illusion!

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise. Looks like 1, 9, and 8 show up first. Then, it learns 5 and 3.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. We just need to pass in a new latent vector $z$ and we'll get new samples!

# %%
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_z = np.random.uniform(-1, 1, size=(16, z_size))
    gen_samples = sess.run(
                   generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                   feed_dict={input_z: sample_z})
view_samples(0, [gen_samples])
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt
# (<matplotlib.figure.Figure at 0x12c0281e978>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B48E9B0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B5091D0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B53E518>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B2C6C18>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B307080>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B35A358>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B3A47F0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B3F8DA0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B66C9B0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B699EF0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B706EB8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B718320>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B7A47B8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B7E1AC8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B8440B8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000012C1B886F60>]], dtype=object))
